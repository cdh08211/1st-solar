# %%
import keras
import numpy as np
import pandas as pd
# Out:
# Using TensorFlow backend.
# c:\users\최동현\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\최동현\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\최동현\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
df = pd.read_csv('c:/jupyter/data2.csv')
df.head()
# Out:
#    year  month  day  time  temperature  land temperature  bright sunshine  \
# 0  2017      7    1     0         25.8              24.7              0.0
# 1  2017      7    1     1         25.6              24.4              0.0
# 2  2017      7    1     2         25.5              24.3              0.0
# 3  2017      7    1     3         25.1              24.2              0.0
# 4  2017      7    1     4         23.9              24.0              0.0
#
#    humidity  wind speed  solar energy production
# 0        84         1.2                      0.0
# 1        84         2.0                      0.0
# 2        84         2.1                      0.0
# 3        86         0.4                      0.0
# 4        90         1.3                      0.0

# %%
x = df.drop(columns=['solar energy production', 'year', 'bright sunshine'])
y = df[['bright sunshine']]

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(7, activation='relu', input_shape=(7,)))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(1))
# Out:
# WARNING:tensorflow:From c:\users\최동현\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(x, y, epochs=60, callbacks=[keras.callbacks.EarlyStopping(patience=5)])
# Out:
# WARNING:tensorflow:From c:\users\최동현\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/60
# 17520/17520 [==============================] - 1s 65us/step - loss: 1.7861
# Epoch 2/60
#  2848/17520 [===>..........................] - ETA: 0s - loss: 0.1107
# c:\users\최동현\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py:569: RuntimeWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 17520/17520 [==============================] - 1s 46us/step - loss: 0.1012
# Epoch 3/60
# 17520/17520 [==============================] - 1s 40us/step - loss: 0.0963
# Epoch 4/60
# ...

# %%
test_data0 = np.array([10, 16, 0, 15.8, 14.662258, 90, 4])
test_data1 = np.array([10, 16, 1, 15.5, 14.437608, 90, 4])
test_data2 = np.array([10, 16, 2, 15.3, 14.373296, 90, 4])
test_data3 = np.array([10, 16, 3, 15.5, 14.72408, 90, 4])
test_data4 = np.array([10, 16, 4, 15.1, 14.453717, 90, 4])
test_data5 = np.array([10, 16, 5, 15.2, 14.705894, 90, 4])
test_data6 = np.array([10, 16, 6, 15.2, 14.658186, 90, 4])
test_data7 = np.array([10, 16, 7, 15.0, 14.363283, 90, 4])
test_data8 = np.array([10, 16, 8, 15.0, 14.665506, 90, 4])
test_data9 = np.array([10, 16, 9, 15.3, 15.525203, 80, 4])
test_data10 = np.array([10, 16, 10, 15.7, 16.613228, 80, 4])
test_data11 = np.array([10, 16, 11, 16.5, 17.790745, 80, 4])
test_data12 = np.array([10, 16, 12, 17.1, 22.456598, 55, 7])
test_data13 = np.array([10, 16, 13, 17.6, 23.804352, 55, 7])
test_data14 = np.array([10, 16, 14, 18.3, 24.960255, 55, 7])
test_data15 = np.array([10, 16, 15, 19.0, 26.82202, 45, 7])
test_data16 = np.array([10, 16, 16, 19.1, 25.59989, 45, 7])
test_data17 = np.array([10, 16, 17, 19.1, 24.153236, 45, 7])
test_data18 = np.array([10, 16, 18, 19.1, 19.785172, 80, 4])
test_data19 = np.array([10, 16, 19, 19.0, 19.419992, 80, 4])
test_data20 = np.array([10, 16, 20, 18.8, 19.042486, 80, 4])
test_data21 = np.array([10, 16, 21, 18.2, 17.244644, 95, 4])
test_data22 = np.array([10, 16, 22, 12, 10.588946, 95, 4])
test_data23 = np.array([10, 16, 23, 12, 10.361619, 95, 4])
print(model.predict(test_data0.reshape(1,7), batch_size=1))
print(model.predict(test_data1.reshape(1,7), batch_size=1))
print(model.predict(test_data2.reshape(1,7), batch_size=1))
print(model.predict(test_data3.reshape(1,7), batch_size=1))
print(model.predict(test_data4.reshape(1,7), batch_size=1))
print(model.predict(test_data5.reshape(1,7), batch_size=1))
print(model.predict(test_data6.reshape(1,7), batch_size=1))
print(model.predict(test_data7.reshape(1,7), batch_size=1))
print(model.predict(test_data8.reshape(1,7), batch_size=1))
print(model.predict(test_data9.reshape(1,7), batch_size=1))
print(model.predict(test_data10.reshape(1,7), batch_size=1))
print(model.predict(test_data11.reshape(1,7), batch_size=1))
print(model.predict(test_data12.reshape(1,7), batch_size=1))
print(model.predict(test_data13.reshape(1,7), batch_size=1))
print(model.predict(test_data14.reshape(1,7), batch_size=1))
print(model.predict(test_data15.reshape(1,7), batch_size=1))
print(model.predict(test_data16.reshape(1,7), batch_size=1))
print(model.predict(test_data17.reshape(1,7), batch_size=1))
print(model.predict(test_data18.reshape(1,7), batch_size=1))
print(model.predict(test_data19.reshape(1,7), batch_size=1))
print(model.predict(test_data20.reshape(1,7), batch_size=1))
print(model.predict(test_data21.reshape(1,7), batch_size=1))
print(model.predict(test_data22.reshape(1,7), batch_size=1))
print(model.predict(test_data23.reshape(1,7), batch_size=1))
# Out:
# [[0.06313235]]
# [[0.06582004]]
# [[0.06765091]]
# [[0.06849548]]
# [[0.07080287]]
# [[0.0682832]]
# [[0.06268334]]
# [[0.06357878]]
# [[0.13023615]]
# [[0.28931946]]
# [[0.31056744]]
# [[0.254223]]
# [[0.8410046]]
# [[0.8384019]]
# [[0.8213681]]
# [[0.9273087]]
# [[0.9336892]]
# [[0.9275999]]
# [[0.10896648]]
# [[0.12397619]]
# [[0.0946002]]
# [[-0.02312326]]
# [[-0.03383291]]
# [[-0.05820692]]
